# %% [markdown]
# # <center>Изучение распределение параметров пассажиров Титаника</center>

# %% [markdown]
# <img src="https://regnum.ru/uploads/pictures/news/2015/11/11/regnum_picture_1447235972282854_normal.jpg" width=70%/>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Загрузим необходимые библиотеки

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Загружаем датасет с информацией о пассажирах Титаника

# %%
df = pd.read_csv('https://raw.githubusercontent.com/amueller/scipy-2017-sklearn/091d371/notebooks/datasets/titanic3.csv')

# %% [markdown]
# ### Смотрим на первые 10 записей из датафрейма

# %%
df.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %% [markdown]
# ### Посчитаем количество выживших

# %%
df['survived'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %% [markdown]
# ### Посмотрим величину максимальной цены за билет

# %%
df['fare'].max()
# Out:
# 512.3292

# %% [markdown]
# ### Посмотрим всю информацию об этих пассажирах

# %%
df[df['fare'] == df['fare'].max()]
# Out:
#      pclass  survived                                               name  \
# 49        1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50        1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 183       1         1                             Lesurer, Mr. Gustave J
# 302       1         1                                   Ward, Miss. Anna
#
#         sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# 49     male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 50   female  58.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 183    male  35.0      0      0  PC 17755  512.3292         B101        C
# 302  female  35.0      0      0  PC 17755  512.3292          NaN        C
#
#     boat  body                                       home.dest
# 49     3   NaN  Austria-Hungary / Germantown, Philadelphia, PA
# 50     3   NaN                    Germantown, Philadelphia, PA
# ...

# %% [markdown]
# ### Посмотрим величину минимальной цены за билет

# %%
df['fare'].min()
# Out:
# 0.0

# %% [markdown]
# ### Посмотрим всю информацию об этих пассажирах

# %%
df[df['fare'] == df['fare'].min()]
# Out:
#       pclass  survived                                   name   sex   age  \
# 7          1         0                 Andrews, Mr. Thomas Jr  male  39.0
# 70         1         0  Chisholm, Mr. Roderick Robert Crispin  male   NaN
# 125        1         0                       Fry, Mr. Richard  male   NaN
# 150        1         0                  Harrison, Mr. William  male  40.0
# 170        1         1                Ismay, Mr. Joseph Bruce  male  49.0
# 223        1         0          Parr, Mr. William Henry Marsh  male   NaN
# 234        1         0        Reuchlin, Jonkheer. John George  male  38.0
# 363        2         0                  Campbell, Mr. William  male   NaN
# 384        2         0         Cunningham, Mr. Alfred Fleming  male   NaN
# 410        2         0       Frost, Mr. Anthony Wood "Archie"  male   NaN
# 473        2         0                   Knight, Mr. Robert J  male   NaN
# 528        2         0            Parkes, Mr. Francis "Frank"  male   NaN
# ...

# %% [markdown]
# ### Распределение возраста. Нормальное распределение

# %%
plt.subplots(figsize = (22,10),)
df = df[df['age'].notna()]
sns.distplot(df['age'], bins = 100, kde = True, rug = False, norm_hist=False);
# Out:
# C:\Users\Zohrab\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Распеделение платы за билет. Экспоненциальное распределение

# %%
plt.subplots(figsize = (22,10),)
df = df[df['fare'].notna()]
sns.distplot(df['fare'], bins = 100, kde = True, rug = False, norm_hist=False);

# %% [markdown]
# ### Распределение количества родственников на борту. Экспоненциальное распределение

# %%
plt.subplots(figsize = (22,10),)
sns.distplot(df['parch'], kde = True, rug = False, norm_hist=False);

# %% [markdown]
# ### Распределение порядкового номера пассажира. Равномерное распределение

# %%
plt.subplots(figsize = (22,10),)
sns.distplot(df.index, bins = 100, kde = True, rug = False, norm_hist=False);
